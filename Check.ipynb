# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

print("Everything working!")
# Out:
# Everything working!

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# Create simple data
data = {'Name': ['Rob', 'Bob', 'Ned'],
        'Score': [85, 92, 78]}

# Make a DataFrame
df = pd.DataFrame(data)
print(df)

# Simple plot
df.plot(x='Name', y='Score', kind='bar')
plt.show()
# Out:
#   Name  Score
# 0  Rob     85
# 1  Bob     92
# 2  Ned     78
